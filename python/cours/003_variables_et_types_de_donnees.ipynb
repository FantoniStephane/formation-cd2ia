# %% [markdown]
# # Variables, constantes et types de données
#
# Ce notebook présente les **variables**, **constantes** et **types de données** fondamentaux en Python : chaînes, entiers, flottants, booléens, tuples, dictionnaires, ensembles et listes. Chaque type est accompagné d'exemples pratiques et de démonstrations exécutables.

# %% [markdown]
# ## Variables et constantes

# %% [markdown]
# Une **variable** est un espace mémoire qui stocke une valeur. Elle peut changer au cours du programme.
#
# Une **constante** est une variable que l'on décide de **ne pas modifier** après son initialisation (même si Python ne l'interdit pas techniquement). Par convention, les constantes sont écrites **en majuscules**.

# %%
# Exemple de variable
nom = "Alice"
age = 25
print(nom, age)

# Exemple de constante (par convention)
PI = 3.14159
print('La valeur de PI est', PI)
# Out:
# Alice 25
# La valeur de PI est 3.14159

# %% [markdown]
# ## Les types de données de base

# %% [markdown]
# Python gère automatiquement le type des variables (typage dynamique). On peut utiliser la fonction `type()` pour connaître le type d'une variable.

# %%
x = 10
y = 3.14
z = "Bonjour"
b = True

print(type(x))  # int
print(type(y))  # float
print(type(z))  # str
print(type(b))  # bool
# Out:
# <class 'int'>
# <class 'float'>
# <class 'str'>
# <class 'bool'>

# %% [markdown]
# ## Les chaînes de caractères (`str`)

# %% [markdown]
# Les chaînes permettent de manipuler du texte. On peut les délimiter par des guillemets simples ' ou doubles ". Elles supportent la concaténation, le slicing et diverses méthodes utiles.
#
# (Référence sur la [doc Python](https://docs.python.org/3/library/stdtypes.html#text-and-binary-sequence-type-methods-summary))

# %%
a = 'Bonjour'
b = "le monde"
message = a + ' ' + b
print(message)

print(a[0])      # B
print(a[:3])     # Bon
print(a[-4:])    # jour
print(len(a))    # longueur
# [x:y:z] x=debut; y=fin; z=step (pas)
# Out:
# Bonjour le monde
# B
# Bon
# jour
# 7

# %% [markdown]
# ### 🔎 Focus sur les chaînes formattées ("f-strings")
#
# Les **f-strings** permettent d'insérer facilement des variables directement dans une chaîne de caractères. On les utilise en plaçant la lettre `f` devant la chaîne, puis en écrivant les variables entre accolades `{}`.
#
# C'est souvent plus lisible et plus pratique que de concaténer plusieurs morceaux de texte.
#
# Dans l'exemple ci-dessous, Python remplace automatiquement les accolades par la valeur des variables.

# %%
prenom = "Lina"
age = 22
ville = "Metz"

message = f"Bonjour, je m'appelle {prenom}, j'ai {age} ans et j'habite à {ville}."

print(message)
# Out:
# Bonjour, je m'appelle Lina, j'ai 22 ans et j'habite à Metz.

# %% [markdown]
# ## Les nombres entiers (`int`) et réels (`float`)

# %% [markdown]
# Les entiers (`int`) représentent des nombres sans décimales, tandis que les flottants (`float`) représentent des nombres à virgule.

# %%
a = 13       # int
b = 3.5      # float
c = a + b

print(a + b)
print(a - b)
print(a * b)
print(a / b)
print(a // b)  # division entière
print(a % 2)   # modulo
print(a ** 2)  # puissance
# Out:
# 16.5
# 9.5
# 45.5
# 3.7142857142857144
# 3.0
# 1
# 169

# %% [markdown]
# ## Les booléens (`bool`)

# %% [markdown]
# Les valeurs booléennes ne peuvent être que `True` ou `False`. Elles sont souvent le résultat d'une comparaison logique.

# %%
x = 5
y = 10
a = False
b = True

print(x < y)   # True
print(x == y)  # False
print(not(x > y))  # True
print(a and b) # False
# Out:
# True
# False
# True
# False

# %% [markdown]
# ## Les tuples (`tuple`)

# %% [markdown]
# Un **tuple** est une **collection ordonnée et immuable**.
# Cela signifie que **l’ordre des éléments est conservé**, mais qu’**on ne peut pas modifier son contenu après sa création** (pas d’ajout, de suppression ou de remplacement d’élément).
#
# Un tuple s’écrit entre **parenthèses `()`**, et ses éléments peuvent être de **types variés** : entiers, chaînes, listes, dictionnaires, etc.
#
# **Caractéristiques principales :**
#
# * Ordonné → on peut accéder aux éléments par leur **index** (`tuple[0]`, `tuple[1]`, …)
# * Immuable → on **ne peut pas** changer les éléments une fois le tuple créé
# * Peut contenir **des doublons** (contrairement aux `set`)
#
# **Utilité des tuples :**
#
# * Stocker des **valeurs fixes** qui ne doivent pas changer (ex. coordonnées GPS, dimensions, constantes).
# * Utiliser comme **clé de dictionnaire** (car immuables).
# * Retourner **plusieurs valeurs** depuis une fonction (Python renvoie naturellement un tuple).

# %%
# Exemple simple
coord = (10, 20)
print(coord[0])  # accès à un élément

x, y = coord  # déballage du tuple
print('x =', x)
print('y =', y)

t = (42,)
print(type(t))  # tuple à un seul élément

# Exemple d'un tuple avec plusieurs types
info = ('Alice', 30, True, ['pomme', 'banane'])
print(info)
# Out:
# 10
# x = 10
# y = 20
# <class 'tuple'>
# ('Alice', 30, True, ['pomme', 'banane'])

# %% [markdown]
# ## Les listes (`list`)

# %% [markdown]
# Une liste est une **collection ordonnée et modifiable**. Elle est très utilisée pour stocker plusieurs valeurs dans un seul objet. Les éléments sont placés entre crochets [].
#
# (Référence sur la [doc Python](https://docs.python.org/3/tutorial/datastructures.html#more-on-lists))

# %%
fruits = ['pomme', 'banane', 'cerise', 'banane']

print(fruits[0])
fruits.append("orange")
print(fruits)

fruits.insert(1, 'kiwi')
print(fruits)

fruits.remove('banane')
print(fruits)

print(len(fruits)) # Note : len() est une fonction qui permet d'afficher la longueur d'un élément.
# Out:
# pomme
# ['pomme', 'banane', 'cerise', 'banane', 'orange']
# ['pomme', 'kiwi', 'banane', 'cerise', 'banane', 'orange']
# ['pomme', 'kiwi', 'cerise', 'banane', 'orange']
# 5

# %% [markdown]
# ## Les ensembles (`set`)

# %% [markdown]
# Un ensemble est une **collection non ordonnée et sans doublons**. Il est pratique pour les opérations d'ensemble : union, intersection, différence.

# %%
animaux = {'chat', 'chien', 'oiseau', 'chat'}
print("Affichage brut d'un set :")
print(animaux) # "chat" ne sera affiche qu'une fois

animaux.add('poisson')
animaux.remove('chien')
print("Après add/remove :")
print(animaux)

autres = {'poisson', 'lapin'}
print("Union / Intersection :")
print(animaux.union(autres)) # Fusionne les deux sets
print(animaux.intersection(autres)) # Affiche les valeurs communes aux deux sets
# Out:
# Affichage brut d'un set :
# {'chat', 'chien', 'oiseau'}
# Après add/remove :
# {'chat', 'poisson', 'oiseau'}
# Union / Intersection :
# {'lapin', 'oiseau', 'chat', 'poisson'}
# {'poisson'}

# %% [markdown]
# ## Les dictionnaires (`dict`)

# %% [markdown]
# Un dictionnaire stocke des **paires clé-valeur**. Les clés doivent être uniques et servent à accéder rapidement aux valeurs associées.

# %%
personne = {
    'nom': 'Dupont',
    'age': 30,
    'ville': 'Paris'
}

# Affichage en ligne possible : personne = {'nom': 'Dupont', 'age': 30, 'ville': 'Paris'}

# Accès à une information du dictionnaire
print(personne['nom'])

# Ajouter ou modifier des clés
personne['age'] = 31
personne['metier'] = 'Développeur'

print(personne)

# Supprimer une clé
del personne['metier']
print(personne) # metier est supprimé
# Out:
# Dupont
# {'nom': 'Dupont', 'age': 31, 'ville': 'Paris', 'metier': 'Développeur'}
# {'nom': 'Dupont', 'age': 31, 'ville': 'Paris'}

# %% [markdown]
# Un dictionnaire peut contenir **d'autres dictionnaires**.
# C’est très utile pour représenter des structures de données complexes (par exemple : plusieurs personnes, produits, élèves…).

# %%
# Dictionnaire imbriqué : une personne contient un sous-dictionnaire 'adresse'
personne = {
    'nom': 'Durand',
    'prenom': 'Sophie',
    'age': 29,
    'profession': 'Architecte',
    'adresse': {
        'rue': '15 rue des Lilas',
        'ville': 'Lyon',
        'code_postal': 69003,
        'pays': 'France'
    }
}

# Accès direct aux clés du dictionnaire principal
print(personne['prenom'], personne['nom'])  # Sophie Durand

# Accès au sous-dictionnaire 'adresse'
print(personne['adresse'])

# Accès à un champ spécifique de l'adresse
print(personne['adresse']['ville'])  # Lyon

# Modification du code postal
personne['adresse']['code_postal'] = 69007

# Affichage complet formaté
print(f"{personne['prenom']} habite au {personne['adresse']['rue']}, "
      f"{personne['adresse']['code_postal']} {personne['adresse']['ville']} ({personne['adresse']['pays']})")

# ☝️ Notez l'utilisation du 'f' avant les double-quotes (") pour utiliser une f-string.
# Out:
# Sophie Durand
# {'rue': '15 rue des Lilas', 'ville': 'Lyon', 'code_postal': 69003, 'pays': 'France'}
# Lyon
# Sophie habite au 15 rue des Lilas, 69007 Lyon (France)

# %% [markdown]
# ## Conversion entre types

# %% [markdown]
# Python permet de convertir les types avec les fonctions :
# * `int()` : pour convertir une donnée en nombre entier
# * `float()` : pour convertir une donnée en nombre à virgule flottante
# * `str()` : pour convertir une donnée en chaîne de caractères
# * `list()` : pour convertir une donnée en une liste
# * `tuple()` : pour convertir une donnée (comme une liste par exemple), en tuple
# * `set()` : pour convertir une donnée (comme une liste par exemple) en set

# %%
a = '123'
b = int(a)
c = float(a)

print(a, type(a))
print(b, type(b))
print(c, type(c))

# ⚠️ Attention, il faut que la donnée 'source'
# soit compatible avec le type de destination.
# L'exemple ci-dessous génèrera une erreur.

# d = "Hello World"
# e = int(d)

liste = [1, 2, 3]
tup = tuple(liste)
print(tup)

ens = {'a', 'b', 'c'}
liste2 = list(ens)
print(liste2)

# Exemple de déduplication
ma_liste = ["burger", "kebab", "tacos", "kebab", "burger", "burger"]
mon_set = set(ma_liste)
ma_liste_sans_doublons = list(mon_set)
print(ma_liste_sans_doublons)
# Out:
# 123 <class 'str'>
# 123 <class 'int'>
# 123.0 <class 'float'>
# (1, 2, 3)
# ['a', 'b', 'c']
# ['burger', 'kebab', 'tacos']

# %% [markdown]
# ## Exercices

# %% [markdown]
# ### Exercice 1: Manipulation de chaînes de caractères
#
# 1. Créez une chaîne de caractères `phrase` contenant "Python est un langage puissant et polyvalent."
# 2. Affichez la longueur de cette phrase.
# 3. Extrayez et affichez les mots "langage puissant" de la phrase en utilisant le slicing.
# 4. Remplacez le mot "puissant" par "extraordinaire" dans la phrase et affichez le résultat.

# %%
# @title
# Solution Exercice 1
phrase = "Python est un langage puissant et polyvalent."
print(f"Longueur de la phrase : {len(phrase)}")

# Trouver les indices pour 'langage puissant'
start = phrase.find('langage puissant')
end = start + len('langage puissant')
print(f"Mots extraits : {phrase[start:end]}")

phrase_modifiee = phrase.replace("puissant", "extraordinaire")
print(f"Phrase modifiée : {phrase_modifiee}")
# Out:
# Longueur de la phrase : 45
# Mots extraits : langage puissant
# Phrase modifiée : Python est un langage extraordinaire et polyvalent.

# %% [markdown]
# ### Exercice 2: Opérations sur les listes
#
# 1. Créez une liste `nombres` contenant les entiers de 1 à 5.
# 2. Ajoutez le nombre 6 à la fin de la liste.
# 3. Insérez le nombre 0 au début de la liste.
# 4. Supprimez le nombre 3 de la liste.
# 5. Affichez la liste finale.

# %%
# Solution Exercice 2
nombres = [1, 2, 3, 4, 5]
print(f"Liste initiale : {nombres}")
nombres.append(6)
print(f"Après ajout de 6 : {nombres}")
nombres.insert(0, 0)
print(f"Après insertion de 0 : {nombres}")
nombres.remove(3)
print(f"Après suppression de 3 : {nombres}")
print(f"Liste finale : {nombres}")
# Out:
# Liste initiale : [1, 2, 3, 4, 5]
# Après ajout de 6 : [1, 2, 3, 4, 5, 6]
# Après insertion de 0 : [0, 1, 2, 3, 4, 5, 6]
# Après suppression de 3 : [0, 1, 2, 4, 5, 6]
# Liste finale : [0, 1, 2, 4, 5, 6]

# %% [markdown]
# ### Exercice 3: Utilisation de dictionnaires
#
# 1. Créez un dictionnaire `produit` avec les clés `nom` (valeur "Ordinateur portable"), `prix` (valeur 1200) et `quantite` (valeur 5).
# 2. Affichez le prix du produit.
# 3. Mettez à jour la quantité à 3.
# 4. Ajoutez une nouvelle clé `fournisseur` avec la valeur "TechCorp".
# 5. Affichez le dictionnaire `produit` mis à jour.

# %%
# Solution Exercice 3
produit = {
    'nom': 'Ordinateur portable',
    'prix': 1200,
    'quantite': 5
}
print(f"Dictionnaire initial : {produit}")
print(f"Prix du produit : {produit['prix']}")

produit['quantite'] = 3
print(f"Après mise à jour de la quantité : {produit}")

produit['fournisseur'] = 'TechCorp'
print(f"Après ajout du fournisseur : {produit}")
print(f"Dictionnaire final : {produit}")

# %% [markdown]
# ### Exercice 4: Conversion de types
#
# 1. Vous avez une chaîne de caractères `chaine_nombre = "42"`.
# 2. Convertissez cette chaîne en un entier et stockez-le dans `entier_nombre`.
# 3. Convertissez `entier_nombre` en un flottant et stockez-le dans `flottant_nombre`.
# 4. Affichez les valeurs et les types de `chaine_nombre`, `entier_nombre` et `flottant_nombre`.

# %%
# Solution Exercice 4
chaine_nombre = "42"
print(f"Chaine : {chaine_nombre}, Type : {type(chaine_nombre)}")

entier_nombre = int(chaine_nombre)
print(f"Entier : {entier_nombre}, Type : {type(entier_nombre)}")

flottant_nombre = float(entier_nombre)
print(f"Flottant : {flottant_nombre}, Type : {type(flottant_nombre)}")
# Out:
# Chaine : 42, Type : <class 'str'>
# Entier : 42, Type : <class 'int'>
# Flottant : 42.0, Type : <class 'float'>

# %% [markdown]
# <small>© Nicolas NUNGE - Version 1.0.2 - octobre 2025</small>
