# %% [markdown]
# # TP Python — Calculateur de devis pour un studio de création
#
# **Formation CD2IA — Metz Numeric School**
# **Auteur du sujet : Nicolas NUNGE — v1.0.0 — avril 2026**
#
# ---
#
# ## Contexte
#
# Tu travailles pour un petit studio de création. Le programme calcule le prix estimé d'un devis selon le type de prestation, le nombre d'heures, l'urgence et la fidélité du client.
#
# ---
#
# ## Prestations
#
# | Prestation | Tarif horaire |
# |------------|---------------|
# | Logo | 70 € / heure |
# | Site | 90 € / heure |
# | Affiche | 50 € / heure |
#
# ---
#
# ## Règles de calcul
#
# - Prix de base = tarif horaire × nombre d'heures
# - Livraison urgente → **+30%**
# - Client fidèle → **-10%** sur le total
#
# ---
#
# ## Contraintes techniques
#
# - `input()`, `int()`, `print()`
# - Plusieurs fonctions avec `def` et `return`

# %% [markdown]
# ---
#
# ## Étape 1 — `obtenir_tarif_horaire()`
#
# Reçoit le type de prestation et retourne le tarif horaire correspondant.

# %%
def obtenir_tarif_horaire(prestation):
    # À compléter
    pass

# %% [markdown]
# ---
#
# ## Étape 2 — `calculer_prix_base()`
#
# Reçoit le tarif horaire et le nombre d'heures, retourne le prix de base.

# %%
def calculer_prix_base(tarif_horaire, nb_heures):
    # À compléter
    pass

# %% [markdown]
# ---
#
# ## Étape 3 — `appliquer_majoration()`
#
# Applique +30% si la livraison est urgente.

# %%
def appliquer_majoration(prix_de_base, urgence, taux=0.3):
    # À compléter
    pass

# %% [markdown]
# ---
#
# ## Étape 4 — `appliquer_reduction_fidelite()`
#
# Applique -10% si le client est fidèle.

# %%
def appliquer_reduction_fidelite(tarif_actuel, fidele, taux=0.1):
    # À compléter
    pass

# %% [markdown]
# ---
#
# ## Étape 5 — `afficher_recap()`
#
# Affiche le récapitulatif du devis.

# %%
def afficher_recap(prestation, nb_heures, prix_final):
    # À compléter
    pass

# %% [markdown]
# ---
#
# ## Étape 6 — Programme principal
#
# Appelle toutes les fonctions dans le bon ordre.

# %%
# À compléter

# %% [markdown]
# ---
#
# ## Exemple de déroulé attendu
#
# ```
# Bienvenue dans le calculateur de devis.
# Type de prestation (logo/site/affiche) : logo
# Nombre d'heures : 5
# Livraison urgente ? (oui/non) : oui
# Client fidèle ? (oui/non) : non
#
# Récapitulatif du devis :
# Prestation : logo
# Nombre d'heures : 5
# Prix final estimé : 455.0 €
# ```
#
# ---
#
# *Have fun ! 🚀*
