# %% [markdown]
# # TP Python — Contrôle d'accès à une zone sécurisée
#
# **Formation CD2IA — Metz Numeric School**
# **Auteur du sujet : Nicolas NUNGE — v1.0.0 — février 2026**
#
# ---
#
# ## Consigne
#
# Écrire un programme Python qui détermine si une personne peut entrer dans une zone sécurisée d'une entreprise.
#
# Le programme doit demander :
# - L'âge de la personne
# - Si elle possède un badge valide
# - Si elle connaît le code d'accès du jour
# - Si elle est accompagnée par un responsable
#
# Le programme doit ensuite afficher si l'accès est autorisé ou refusé, avec la bonne raison.
#
# ---
#
# ## Règles à appliquer dans l'ordre
#
# | Règle | Condition | Résultat |
# |---|---|---|
# | 1 | Âge < 18 | Accès refusé (mineur) |
# | 2 | Badge valide ET code du jour | Accès autorisé |
# | 2 | Accompagné par un responsable | Accès autorisé |
# | 3 | Ni autorisations ni accompagnateur | Accès refusé |
# | 4 | Badge valide MAIS pas le code | Message spécifique |
# | 5 | Code correct MAIS pas de badge | Message spécifique |
#
# ---
#
# ## Contraintes
#
# Ton programme doit utiliser :
# - `input()`
# - `int()`
# - Plusieurs conditions `if / elif / else`
# - Au moins un `and`
# - Au moins un `or`

# %% [markdown]
# ---
#
# ## Conseil avant de coder
#
# Remplis ce tableau à la main avant d'écrire une seule ligne de code :
#
# | Âge | Badge | Code | Accompagnateur | Résultat attendu |
# |-----|-------|------|----------------|------------------|
# | 16 | oui | oui | non | Refusé : mineur |
# | 28 | oui | oui | non | Autorisé : accès complet |
# | 35 | non | non | oui | Autorisé : avec accompagnement |
# | 30 | oui | non | non | Refusé : code manquant |
# | 41 | non | oui | non | Refusé : badge manquant |
# | 25 | non | non | non | Refusé : autorisations insuffisantes |

# %% [markdown]
# ---
#
# ## Étape 1 — Saisies utilisateur
#
# Demande les 4 informations à l'utilisateur et stocke-les dans des variables.

# %%
# À compléter

# %% [markdown]
# ---
#
# ## Étape 2 — Logique d'accès
#
# Applique les règles dans l'ordre avec des conditions `if / elif / else`.

# %%
# À compléter

# %% [markdown]
# ---
#
# ## Exemples de sorties attendues
#
# ```
# # Exemple 1
# Quel âge avez-vous ? 16
# → Accès refusé : zone interdite aux mineurs.
#
# # Exemple 2
# Quel âge avez-vous ? 28
# → Accès autorisé : accès complet validé.
#
# # Exemple 3
# Quel âge avez-vous ? 35
# → Accès autorisé : entrée autorisée avec accompagnement.
#
# # Exemple 4
# Quel âge avez-vous ? 30
# → Accès refusé : badge valide, mais code du jour manquant.
#
# # Exemple 5
# Quel âge avez-vous ? 41
# → Accès refusé : code correct, mais badge valide manquant.
#
# # Exemple 6
# Quel âge avez-vous ? 25
# → Accès refusé : autorisations insuffisantes.
# ```
#
# ---
#
# *Have fun ! 🚀*
