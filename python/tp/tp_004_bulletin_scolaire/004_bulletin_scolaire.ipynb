# %% [markdown]
# # TP Python — Le bulletin scolaire
#
# **Formation CD2IA — Metz Numeric School**
# **Auteur du sujet : Nicolas NUNGE — v1.0.0 — avril 2026**
#
# ---
#
# ## Contexte
#
# Développer un programme Python qui aide à analyser les résultats d'un élève.
#
# Le programme demande plusieurs notes, calcule la moyenne, détermine une mention, puis affiche un bilan final.
#
# ---
#
# ## Matières à gérer
#
# 3 notes pour chacune des matières suivantes :
# - Mathématiques
# - Français
# - Anglais
#
# ---
#
# ## Mentions
#
# | Moyenne | Mention |
# |---------|----------|
# | < 10 | Ajourné |
# | 10 à < 12 | Passable |
# | 12 à < 14 | Assez bien |
# | 14 à < 16 | Bien |
# | ≥ 16 | Très bien |
#
# ---
#
# ## Contraintes techniques
#
# - `input()`, `float()`, `print()`
# - Plusieurs fonctions avec `def` et `return`

# %% [markdown]
# ---
#
# ## Étape 1 — Fonction `demande_notes()`
#
# Reçoit le nom d'une matière, demande 3 notes et les retourne dans une liste.

# %%
def demande_notes(nom, nb_notes=3):
    # À compléter
    pass

# %% [markdown]
# ---
#
# ## Étape 2 — Fonction `calculer_moyenne()`
#
# Reçoit une liste de notes et retourne leur moyenne.

# %%
def calculer_moyenne(notes):
    # À compléter
    pass

# %% [markdown]
# ---
#
# ## Étape 3 — Fonction `determiner_mention()`
#
# Reçoit une moyenne et retourne la mention correspondante.

# %%
def determiner_mention(moyenne):
    # À compléter
    pass

# %% [markdown]
# ---
#
# ## Étape 4 — Fonction `afficher_bilan_final()`
#
# Orchestre tout le programme et affiche le bilan complet.

# %%
def afficher_bilan_final():
    # À compléter
    pass


afficher_bilan_final()

# %% [markdown]
# ---
#
# ## Exemple de déroulé attendu
#
# ```
# Bienvenue dans le simulateur de bulletin scolaire.
#
# Saisir les 3 notes de mathématiques :
# Note 1 : 12
# Note 2 : 15
# Note 3 : 9
#
# Saisir les 3 notes de français :
# Note 1 : 11
# Note 2 : 13
# Note 3 : 14
#
# Saisir les 3 notes d'anglais :
# Note 1 : 16
# Note 2 : 15
# Note 3 : 17
#
# Bilan de l'élève :
# Moyenne de mathématiques : 12.00
# Moyenne de français : 12.67
# Moyenne d'anglais : 16.00
# Moyenne générale : 13.56
# Mention : Assez bien
# ```
#
# ---
#
# *Have fun ! 🚀*
