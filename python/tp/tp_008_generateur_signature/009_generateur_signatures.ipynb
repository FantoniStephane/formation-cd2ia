# %% [markdown]
# # TP Python — Générateur de signatures d'email
#
# **Formation CD2IA — Metz Numeric School**
# **Auteur du sujet : Nicolas NUNGE — v1.0.0 — juin 2025**
#
# ---
#
# ## Objectif
#
# Générer automatiquement une signature d'e-mail professionnelle à partir d'informations saisies par l'utilisateur.
#
# **Notions travaillées :** fonctions, paramètres, valeurs par défaut, retour de valeur.
#
# ---
#
# ## Valeurs par défaut
#
# | Champ | Valeur par défaut |
# |-------|------------------|
# | Nom | Dupont |
# | Prénom | Jean |
# | Poste | Collaborateur |
# | Téléphone | N/A |
# | E-mail | prenom.nom@entreprise.com |
#
# ---
#
# ## Format de la signature
#
# ```
# Prénom NOM
# Poste
# Tél : <numéro>
# Email : <adresse e-mail>
# ```

# %% [markdown]
# ---
#
# ## Étape 1 — `input_default()`
#
# Retourne la saisie utilisateur ou la valeur par défaut si le champ est laissé vide.

# %%
def input_default(prompt, default_value="N/A"):
    # À compléter
    pass

# %% [markdown]
# ---
#
# ## Étape 2 — `generer_email_defaut()`
#
# Génère une adresse e-mail par défaut à partir du nom et du prénom.

# %%
def generer_email_defaut(nom, prenom):
    # À compléter
    pass

# %% [markdown]
# ---
#
# ## Étape 3 — `saisir_informations()`
#
# Demande les 5 informations à l'utilisateur et retourne un dictionnaire.

# %%
def saisir_informations():
    # À compléter
    pass

# %% [markdown]
# ---
#
# ## Étape 4 — `generer_signature()`
#
# Reçoit le dictionnaire d'infos et affiche la signature formatée.

# %%
def generer_signature(infos):
    # À compléter
    pass

# %% [markdown]
# ---
#
# ## Étape 5 — `main()`
#
# Affiche le message d'accueil et appelle les fonctions dans le bon ordre. Pas de logique métier ici.

# %%
def main():
    # À compléter
    pass


main()

# %% [markdown]
# ---
#
# ## Exemples de déroulé attendu
#
# ```
# # Exemple 1 — saisie complète
# === Générateur de signature e-mail ===
#
# Nom : Martin
# Prénom : Elise
# Poste : Responsable RH
# Téléphone : 06 12 34 56 78
# Adresse e-mail :
#
# --- SIGNATURE GÉNÉRÉE ---
# Elise MARTIN
# Responsable Rh
# Tél : 06 12 34 56 78
# Email : elise.martin@entreprise.com
#
# # Exemple 2 — valeurs par défaut
# === Générateur de signature e-mail ===
#
# Nom :
# Prénom :
# Poste :
# Téléphone :
# Adresse e-mail :
#
# --- SIGNATURE GÉNÉRÉE ---
# Jean DUPONT
# Collaborateur
# Tél : N/A
# Email : jean.dupont@entreprise.com
# ```
