# %% [markdown]
# # TP Python — Le péage autoroutier
#
# **Formation CD2IA — Metz Numeric School**
# **Auteur du sujet : Nicolas NUNGE — v1.0.0 — avril 2026**
#
# ---
#
# ## Contexte
#
# Développer un programme Python qui simule le fonctionnement d'un péage autoroutier.
#
# Lorsqu'un véhicule arrive, le programme pose plusieurs questions pour déterminer le montant à payer.
#
# ---
#
# ## Données de départ
#
# | Véhicule | Tarif de base |
# |----------|---------------|
# | Moto | 2 € |
# | Voiture | 5 € |
# | Camion | 10 € |
#
# Réductions :
# - Abonnement → **-2 €**
# - Voiture avec ≥ 4 passagers → **-1 €**
#
# Règles spéciales :
# - Un camion avec moins de 1 passager → **saisie invalide**
# - Type de véhicule non reconnu → **redemander**
# - Le prix final **ne peut jamais être négatif**
#
# ---
#
# ## Contraintes techniques
#
# - `input()` pour chaque information
# - `int()` pour convertir le nombre de passagers
# - Au moins une boucle `while`
# - Plusieurs conditions `if / elif / else`

# %% [markdown]
# ---
#
# ## Étape 1 — Tarifs de base
#
# Stocke les tarifs dans un dictionnaire.

# %%
# À compléter

# %% [markdown]
# ---
#
# ## Étape 2 — Saisies et validations
#
# Demande le type de véhicule, le nombre de passagers et l'abonnement.
# Recommence si une saisie est invalide.

# %%
# À compléter

# %% [markdown]
# ---
#
# ## Étape 3 — Calcul du tarif
#
# Applique les réductions selon les règles. Protège contre un prix négatif.

# %%
# À compléter

# %% [markdown]
# ---
#
# ## Étape 4 — Affichage final
#
# Affiche le tarif final et autorise le passage.

# %%
# À compléter

# %% [markdown]
# ---
#
# ## Exemples de déroulé attendu
#
# ```
# # Exemple 1
# Bienvenue au péage automatique.
# Type de véhicule : voiture
# Nombre de passagers : 4
# Abonnement ? (o/n) : o
# Tarif initial : 5 €
# Réduction covoiturage : 1 €
# Réduction abonnement : 2 €
# Tarif final : 2 €
# Passage autorisé.
#
# # Exemple 2
# Type de véhicule : avion
# Type de véhicule invalide.
# Veuillez recommencer.
#
# # Exemple 3
# Type de véhicule : camion
# Nombre de passagers : 0
# Saisie invalide.
# Veuillez recommencer.
# ```
#
# ---
#
# *Have fun ! 🚀*
