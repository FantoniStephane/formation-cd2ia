# %% [markdown]
# # TP Python — Générateur de participants fictifs pour une conférence
#
# **Formation CD2IA — Metz Numeric School**
# **Auteur du sujet : Nicolas NUNGE — v1.0.0 — avril 2026**
#
# ---
#
# ## Contexte
#
# Une entreprise veut tester son outil de gestion de participants avant une conférence. Tu vas générer des profils fictifs via une API publique.
#
# ---
#
# ## API à utiliser
#
# ```
# https://randomuser.me/api/?results=10
# ```
#
# Documentation : https://randomuser.me/documentation
#
# ---
#
# ## Informations à afficher par participant
#
# - Prénom + Nom
# - Email
# - Ville
# - Pays
# - Nationalité
#
# ---
#
# ## Contraintes techniques
#
# - Module `requests`
# - Requête GET + `.json()`
# - Boucle pour parcourir les résultats
# - Plusieurs fonctions avec `def`
# - Validation de la saisie utilisateur

# %% [markdown]
# ---
#
# ## Étape 1 — Import

# %%
import requests

# %% [markdown]
# ---
#
# ## Étape 2 — `build_url()`
#
# Reçoit le nombre de participants et retourne l'URL complète à appeler.

# %%
def build_url(nb_participants):
    # À compléter
    pass

# %% [markdown]
# ---
#
# ## Étape 3 — `ask_api()`
#
# Envoie la requête GET et retourne les données JSON. Gère les erreurs réseau.

# %%
def ask_api(url):
    # À compléter
    pass

# %% [markdown]
# ---
#
# ## Étape 4 — `extract_info_user()`
#
# Reçoit un utilisateur du JSON et retourne un dictionnaire avec les infos utiles.

# %%
def extract_info_user(user):
    # À compléter
    pass

# %% [markdown]
# ---
#
# ## Étape 5 — `afficher_badge_participant()`
#
# Affiche proprement les informations d'un participant.

# %%
def afficher_badge_participant(infos):
    # À compléter
    pass

# %% [markdown]
# ---
#
# ## Étape 6 — `main()`
#
# Coordonne l'exécution du programme.

# %%
def main():
    # À compléter
    pass


main()

# %% [markdown]
# ---
#
# ## Exemple de déroulé attendu
#
# ```
# Bienvenue dans le générateur de participants fictifs.
#
# Combien de participants voulez-vous générer ? : 3
#
# Récupération des participants...
#
# --- Participant 1 ---
# Nom complet : Emma Martin
# Email       : emma.martin@example.com
# Ville       : Paris
# Pays        : France
# Nationalité : FR
# ```
#
# ---
#
# *Have fun ! 🚀*
